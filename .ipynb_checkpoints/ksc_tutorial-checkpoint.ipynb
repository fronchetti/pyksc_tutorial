# %% [markdown]
# **Important: The PyKSC module was implemented in Python 2.7, and its current version might not work in Python 3 or above.**

# %% [markdown]
# # Grouping discussions  with PyKSC
#
# First, install and load the necessary modules:

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import os
import numpy
# Source code: https://github.com/flaviovdf/pyksc
from pyksc import ksc
from pyksc import metrics
from csv import DictReader, DictWriter
import matplotlib.pyplot as plt

# %% [markdown]
# Use the method below to load the data from the discussions file:

# %%
def load_discussions(csv_filepath):
    csv_file = open(csv_filepath , 'r')
    discussions = DictReader(csv_file)

    time_series = []
    projects = []

    for discussion in discussions:
        discussion_time_series = [discussion[column] for column in discussions.fieldnames if column not in ['project']]
        time_series.append(discussion_time_series)
        projects.append(discussion['project'])

    time_series = numpy.array(time_series, dtype=numpy.double)
    
    return projects, time_series

# %%
projects, time_series = load_discussions('./discussions.csv')

# %% [markdown]
# Create the images folder if it does not exist:

# %%
if not os.path.exists('./images'):
    os.makedirs('./images')

# %% [markdown]
# Create the method get_clusters to implement the KSC algorithm. Such algorithm receives a list of time series, and groups them in k clusters:

# %%
def get_clusters(time_series, k):
    clusters = {}
    centroids, assign, best_shift, cent_dists = ksc.ksc(time_series, k)

    if assign is not None:
        for series, cluster in zip(time_series, assign):
            if cluster in clusters.keys():
                clusters[cluster].append(series)
            else:
                clusters[cluster] = [series]

    return clusters, centroids, assign, best_shift, cent_dists

# %% [markdown]
# **Although you could use get_clusters with an arbitrary value of k, we recommend the use of an heuristic to identify the optimal number of clusters for your data set.**
#
# Implement the βCV heuristic to identify the optimal number of k clusters for the data set of discussions:

# %%
def get_beta_cv(time_series, min_cl = 2, max_cl = 16):
    print("Saving βCV values in 'beta_cv.txt' file")

    beta_cv = []
    k_possible_values = [k for k in range(min_cl, max_cl)]

    with open('./beta_cv.txt', 'w') as text_file:
        text_file.write('# βCV (for 2 ≤ k ≤ 15):\n')

        for k in k_possible_values:
            _, _, assign, _, _ = get_clusters(time_series, k)
            ratio = metrics.beta_cv(time_series, assign)
            text_file.write(str(k) + ': ' + str(ratio) + '\n')
            beta_cv.append(ratio)

    return beta_cv

def plot_beta_cv(beta_cv):
    k_values = [k for k in range(len(beta_cv))]

    figure = plt.figure()
    plt.plot(k_values, beta_cv, color='black')
    plt.xlabel('# Clusters', fontsize = 14)
    plt.ylabel(r'$\beta$cv', fontsize = 14)
    plt.title(r'$\beta$cv for 2 $\leq$ k $\leq$ 15')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    
    figure.savefig('./images/beta_cv.png', bbox_inches='tight', format='png', dpi=1000)

# %% [markdown]
# Run get_beta_cv to calculate the heuristic values.
#
# **This process may take a while. Notice that you can specify the range of k values to be tested by using the parameters min_cl (Default: 2) and max_cl (Default: 16).**

# %%
beta_cv_values = get_beta_cv(time_series)
# Out:
# Saving βCV values in 'beta_cv.txt' file

# %% [markdown]
# Run plot_beta_cv using the output of get_beta_cv to visualize the βCV ratio for each possible number of clusters. **According to the heuristic, the smallest value of k after which the βCV ratio remains rougly stable should be selected.**

# %%
for index, ratio in enumerate(beta_cv_values):
    print(index + 2, ratio)

plot_beta_cv(beta_cv_values)
# Out:
# (2, 0.7684686636668553)
# (3, 0.744451982081287)
# (4, 0.9227012256514452)
# (5, 0.9162566315990657)
# (6, 0.9840701431357747)
# (7, 0.8928466980466109)
# (8, 1.1083892548289431)
# (9, 0.9590662406907833)
# (10, 0.8591776789329802)
# (11, 0.994561444269243)
# (12, 0.9589999738275314)
# (13, 1.0473425982209172)
# (14, 0.9533021578683061)
# (15, 0.9921849548060175)

# %% [markdown]
# In our case, we decided to keep with k = 4, but k = 2 also seems reasonable.

# %% [markdown]
# Now that we know what is the optimal value for k, we can run get_clusters with k = 4 and plot the clusters and centroids.
#
# First, let's implement the methods to plot them:

# %%
def plot_clusters(clusters):
    time_range = None 

    for cluster in clusters.keys():
        figure = plt.figure()
        plt.ylim([0, 1000])
        plt.xlabel('Weeks', fontsize = 16)
        plt.ylabel('# Open Discussions', fontsize = 16)
        plt.xticks(fontsize = 14)
        plt.yticks(fontsize = 14)

        for time_series in clusters[cluster]:

            # Defines the values for the x axis
            if time_range is None:
                time_range = [-i for i in range(len(time_series) - 1, -1, -1)]
                plt.xlim([min(time_range), max(time_range)])

            plt.plot(time_range, time_series, color=clusters_colors[cluster])

        filename = os.path.join('images/cluster_' + str(cluster) + '.png')

        if os.path.isfile(filename):
            os.remove(filename)

        figure.savefig(filename, bbox_inches='tight', format='png', dpi=1000)

# %%
def plot_centroids(centroids):
    time_range = None

    for cluster, centroid in enumerate(centroids):

        if time_range is None:
            time_range = [-i for i in range(len(centroid) - 1, -1, -1)]

        figure = plt.figure()
        plt.ylim([0, 1.0])
        plt.xlim([min(time_range), max(time_range)])
        plt.xlabel('Weeks', fontsize=16)
        plt.ylabel('Average', fontsize=16)
        plt.xticks(fontsize=14)
        plt.yticks(fontsize=14)

        plt.plot(time_range, centroid, color=clusters_colors[cluster])
        
        figure.savefig('images/centroid_' + str(cluster) + '.png', bbox_inches='tight', format='png', dpi=1000)

# %% [markdown]
# Get the groups of projects with k = 4 (optimal):

# %%
clusters, centroids, assign, _, _  = get_clusters(time_series, 4)

# %% [markdown]
# Assign colors for each cluster and and plot them:

# %%
clusters_colors = ['darkorange', 'forestgreen', 'royalblue', 'firebrick']
plot_clusters(clusters)

# %% [markdown]
# Now, plot the centroids:

# %%
plot_centroids(centroids)

# %% [markdown]
# We can also use the centroid values to identify trendlines using Microsoft Excel (or similar). For this reason, we also implemented a method to export these values to a text file:

# %%
def export_centroids(centroids):
    with open('./centroids.txt', 'w') as text_file:
        print('Saving K-Spectral Centroids (KSC) in "centroids.txt" file')
        text_file.write('\n# K-Spectral Centroids (KSC):\n')

        for cluster, centroid in enumerate(centroids):
            growth_rate = centroid[0] + centroid[-1] * 100
            text_file.write("Centroid for Cluster #" + str(cluster) + "\n")
            text_file.write("Growth Rate: " + str(cluster) + "\n")

            for value in centroid:
                text_file.write(str(value) + '\n')

# %%
export_centroids(centroids)
# Out:
# Saving K-Spectral Centroids (KSC) in "centroids.txt" file

# %% [markdown]
# Finally, we can also save the projects' name per cluster using the method below:

# %%
def export_projects_per_cluster(projects, assign):
    print('Saving projects per cluster in projects_in_cluster_k files')
    clusters = {}

    for project, cluster in zip(projects, assign):
        if cluster in clusters.keys():
            clusters[cluster].append(project)
        else:
            clusters[cluster] = [project]
    
    for cluster in clusters:
        with open ('projects_in_cluster_' + str(cluster) + '.csv', 'w') as csv_file:
            for project in clusters[cluster]:
                csv_file.write(project + '\n')

# %%
export_projects_per_cluster(projects, assign)
# Out:
# Saving projects per cluster in projects_in_cluster_k files

# %% [markdown]
# This is the end, thank you for your time!
#
# **If you have any further questions related to this notebook, feel free to send me a message at: fronchettl@vcu.edu**
